# %%
import pandas as pd

df = pd.read_csv('../skill_audit/data.csv')
df.head()
# Out:
#       Name  Age  Salary
# 0    Alice   28   50000
# 1      Bob   22   35000
# 2  Charlie   30   60000
# 3    Diana   24   40000

# %%
avg_salary_above_25 = df[df['Age']>25]['Salary'].mean()
print(avg_salary_above_25)
# Out:
# 55000.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
sns.barplot(data=df, x="Name", y="Salary")
plt.title("Bar Graph of Salary of Each Individuals")
plt.show()
